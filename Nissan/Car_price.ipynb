# %% [markdown]
# ## Plan of attack:
# 1. Clean the data - take mean/median or delete null - try 2 iterations
# 2. Separate data into train & test sets
# 3. use linear regression / related model based based fit functions to check if anything makes sense
# 4. Levy PCA on data to reduce dimensionality
# 5. Perform trainings on different models from given data
# 6. select the best model & re-iterate for different parameters

# %%
import pandas as pd
import tensorflow.compat.v2.feature_column as fc
import tensorflow as tf

# %%
# Read df
car_excel = pd.read_csv('CarPrice_Assignment.csv')
# Replace missing values with mean values  
column_means = car_excel.mean() # TODO: solve type error
car_excel = car_excel.fillna(column_means)
car_excel.pop('car_ID') # ID Irrelevant to pricing 
car_excel.head()
# Out:
# C:\Users\Batman\AppData\Local\Temp/ipykernel_2308/265911229.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   column_means = car_excel.mean() # TODO: solve type error
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# 0       130.0        mpfi       3.47   2.68              9.0         111
# 1       130.0        mpfi       3.47   2.68              9.0         111
# 2       152.0        mpfi       2.68   3.47              9.0         154
# 3       109.0        mpfi       3.19   3.40             10.0         102
# 4       136.0        mpfi       3.19   3.40              8.0         115
#
#   peakrpm  citympg  highwaympg    price
# 0    5000     21.0          27  13495.0
# 1    5000     21.0          27  16500.0
# 2    5000     19.0          26  16500.0
# 3    5500     24.0          30  13950.0
# 4    5500     18.0          22  17450.0
#
# [5 rows x 25 columns]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(car_excel, test_size=0.15)
train.head()
# Out:
#      symboling               CarName fueltype aspiration doornumber  \
# 94           1           nissan leaf      gas        std        two
# 174         -1      toyota celica gt   diesel      turbo       four
# 23           1            dodge d200      gas      turbo        two
# 88          -1  mitsubishi mirage g4      gas        std       four
# 135          2            saab 99gle      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 94       sedan        fwd          front   94.50000      165.3  ...
# 174      sedan        fwd          front  102.40000      175.6  ...
# 23   hatchback        fwd          front   99.00102      157.3  ...
# 88       sedan        fwd          front   96.30000      172.4  ...
# 135      sedan        fwd          front   99.10000      186.6  ...
#
#      enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# 94         97.0        2bbl       3.15   3.29              9.4          69
# 174       110.0         idi       3.27   3.35             22.5          73
# 23         98.0        mpfi       3.03   3.39              7.6         102
# 88        110.0        spdi       3.17   3.46              7.5         116
# 135       121.0        mpfi       3.54   3.07              9.3         110
#
#     peakrpm    citympg  highwaympg    price
# 94     5200  31.000000          37   7299.0
# 174    4500  30.000000          33  10698.0
# 23     5500  24.994924          30   7957.0
# 88     5500  23.000000          30   9279.0
# 135    5250  21.000000          28  15510.0
#
# [5 rows x 25 columns]

# %%
y_train = train.pop('price')
y_test = test.pop('price')

# y_train.head()
train.head()
# Out:
#      symboling               CarName fueltype aspiration doornumber  \
# 94           1           nissan leaf      gas        std        two
# 174         -1      toyota celica gt   diesel      turbo       four
# 23           1            dodge d200      gas      turbo        two
# 88          -1  mitsubishi mirage g4      gas        std       four
# 135          2            saab 99gle      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 94       sedan        fwd          front   94.50000      165.3  ...
# 174      sedan        fwd          front  102.40000      175.6  ...
# 23   hatchback        fwd          front   99.00102      157.3  ...
# 88       sedan        fwd          front   96.30000      172.4  ...
# 135      sedan        fwd          front   99.10000      186.6  ...
#
#      cylindernumber  enginesize  fuelsystem boreratio stroke  \
# 94             four        97.0        2bbl      3.15   3.29
# 174            four       110.0         idi      3.27   3.35
# 23             four        98.0        mpfi      3.03   3.39
# 88             four       110.0        spdi      3.17   3.46
# 135            four       121.0        mpfi      3.54   3.07
#
#      compressionratio horsepower  peakrpm    citympg  highwaympg
# 94                9.4         69     5200  31.000000          37
# 174              22.5         73     4500  30.000000          33
# 23                7.6        102     5500  24.994924          30
# 88                7.5        116     5500  23.000000          30
# 135               9.3        110     5250  21.000000          28
#
# [5 rows x 24 columns]

# %%
# Separate train data into categorical & numerical

CATEGORICAL_COLUMNS = ['symboling','CarName','fueltype','aspiration','doornumber','carbody','drivewheel',
'enginelocation','enginetype','cylindernumber','fuelsystem']

NUMERIC_COLUMNS = ['wheelbase','fare', 'carlength','carwidth','carheight','curbweight','enginesize','boreratio','stroke','compressionratio','horsepower',
'peakrpm',	'citympg',	'highwaympg']

feature_columns = []
for feature_name in CATEGORICAL_COLUMNS:
    vocabulary = train[feature_name].unique()  # gets a list of all unique values from given feature column
    feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

for feature_name in NUMERIC_COLUMNS:
    feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))

print(feature_columns)
# Out:
# [VocabularyListCategoricalColumn(key='symboling', vocabulary_list=(1, -1, 2, 3, 0, -2), dtype=tf.int64, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='CarName', vocabulary_list=('nissan leaf', 'toyota celica gt', 'dodge d200', 'mitsubishi mirage g4', 'saab 99gle', 'vw dasher', 'renault 12tl', 'chevrolet monte carlo', 'jaguar xf', 'nissan note', 'dodge challenger se', 'maxda rx3', 'volkswagen dasher', 'plymouth cricket', 'volvo 145e (sw)', 'audi 100ls', 'vokswagen rabbit', 'subaru dl', 'dodge monaco (sw)', 'vw rabbit', 'alfa-romero stelvio', 'plymouth valiant', 'subaru trezia', 'nissan clipper', 'peugeot 604sl', 'volkswagen super beetle', 'volkswagen 411 (sw)', 'volvo 144ea', 'mazda rx-7 gs', 'subaru r1', 'nissan fuga', 'peugeot 505s turbo diesel', 'toyota corolla', 'volvo diesel', 'plymouth fury iii', 'toyota celica gt liftback', 'honda civic', 'mazda rx-4', 'audi 5000s (diesel)', 'mazda 626', 'chevrolet impala', 'toyouta tercel', 'honda prelude', 'mazda glc', 'toyota corolla 1200', 'honda accord lx', 'mitsubishi g4', 'toyota corolla liftback', 'jaguar xk', 'nissan juke', 'toyota cressida', 'audi 4000', 'toyota corona', 'peugeot 504', 'mitsubishi mirage', 'bmw 320i', 'toyota mark ii', 'nissan teana', 'buick opel isuzu deluxe', 'isuzu D-Max ', 'subaru brz', 'audi fox', 'mitsubishi outlander', 'audi 100 ls', 'subaru', 'buick century special', 'bmw x3', 'toyota carina', 'maxda glc deluxe', 'toyota starlet', 'nissan kicks', 'porcshce panamera', 'isuzu D-Max V-Cross', 'nissan rogue', 'toyota corolla tercel', 'mitsubishi pajero', 'volvo 264gl', 'volkswagen type 3', 'dodge rampage', 'volvo 244dl', 'nissan gt-r', 'alfa-romero giulia', 'dodge colt hardtop', 'mitsubishi lancer', 'nissan otti', 'saab 99e', 'peugeot 304', 'dodge colt (sw)', 'isuzu MU-X', 'jaguar xj', 'bmw x4', 'plymouth satellite custom (sw)', 'saab 99le', 'alfa-romero Quadrifoglio', 'volkswagen rabbit custom', 'toyota tercel', 'buick century luxus (sw)', 'renault 5 gtl', 'mitsubishi montero', 'plymouth duster', 'nissan latio', 'bmw x1', 'honda civic 1300', 'porsche cayenne', 'buick skyhawk', 'volkswagen rabbit', 'subaru tribeca', 'bmw x5', 'nissan titan', 'audi 5000', 'honda accord', 'buick regal sport coupe (turbo)', 'buick electra 225 custom', 'peugeot 504 (sw)', 'mazda glc custom l', 'mercury cougar', 'subaru r2', 'plymouth fury gran sedan', 'toyota corona mark ii', 'subaru baja', 'chevrolet vega 2300', 'toyota corolla 1600 (sw)', 'mazda glc deluxe', 'toyota corona hardtop', 'buick century', 'volkswagen model 111', 'dodge dart custom', 'volvo 245', 'honda civic cvcc', 'buick skylark', 'porsche boxter', 'honda civic (auto)'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='fueltype', vocabulary_list=('gas', 'diesel'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='aspiration', vocabulary_list=('std', 'turbo'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='doornumber', vocabulary_list=('two', 'four'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='carbody', vocabulary_list=('sedan', 'hatchback', 'convertible', 'wagon', 'hardtop'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='drivewheel', vocabulary_list=('fwd', 'rwd', '4wd'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='enginelocation', vocabulary_list=('front', 'rear'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='enginetype', vocabulary_list=('ohc', 'dohc', 'ohcf', 'ohcv', 'l', 'rotor'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='cylindernumber', vocabulary_list=('four', 'six', 'five', 'two', 'three', 'twelve', 'eight'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='fuelsystem', voc ...

# %%
def make_input_fn(data_df, label_df, num_epochs=20, shuffle=True, batch_size=32):
    def input_function():  # inner function, this will be returned
        ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))  # create tf.data.Dataset object with data and its label
        if shuffle:
            ds = ds.shuffle(1000)  # randomize order of data
        ds = ds.batch(batch_size).repeat(num_epochs)  # split dataset into batches of 32 and repeat process for number of epochs
        return ds  # return a batch of the dataset
    return input_function  # return a function object for use

train_input_fn = make_input_fn(train, y_train)  # here we will call the input_function that was returned to us to get a dataset object we can feed to the model
eval_input_fn = make_input_fn(test, y_test, num_epochs=1, shuffle=False)

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
# Create a linear estimtor by passing the feature columns we created earlier
linear_est.train(input_fn=train_input_fn)
result = linear_est.evaluate(eval_input_fn)

clear_output()
print(result['accuracy'])
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Batman\AppData\Local\Temp\tmpguou926r
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Batman\\AppData\\Local\\Temp\\tmpguou926r', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\training_util.py:400: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py:1468: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   self.bias = self.add_variable(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2308/2619497392.py in <module>
#       1 linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
#       2 # Create a linear estimtor by passing the feature columns we created earlier
# ----> 3 linear_est.train(input_fn=train_input_fn)
#       4 result = linear_est.evaluate(eval_input_fn)
#       5
#
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     358
#     359       saving_listeners = _check_listeners_type(saving_listeners)
# --> 360       loss = self._train_model(input_fn, hooks, saving_listeners)
#     361       logging.info('Loss for final step: %s.', loss)
#     362       return self
#
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1184       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1185     else:
# -> 1186       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1187
#    1188   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1212           self._get_features_and_labels_from_input_fn(input_fn, ModeKeys.TRAIN))
#    1213       worker_hooks.extend(input_hooks)
# -> 1214       estimator_spec = self._call_model_fn(features, labels, ModeKeys.TRAIN,
#    1215                                            self.config)
#    1216       global_step_tensor = tf.compat.v1.train.get_global_step(g)
#
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1172
#    1173     logging.info('Calling model_fn.')
# -> 1174     model_fn_results = self._model_fn(features=features, **kwargs)
#    1175     logging.info('Done calling model_fn.')
#    1176
#
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py in _model_fn(features, labels, mode, config)
#     932     def _model_fn(features, labels, mode, config):
#     933       """Call the defined shared _linear_model_fn."""
# --> 934       return _linear_model_fn_v2(
#     935           features=features,
#     936           labels=labels,
#
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py in _linear_model_fn_v2(***failed resolving arguments***)
#     660                           optimizer)
#     661   else:
# --> 662     logits, trainable_variables = _linear_model_fn_builder_v2(
#     663         units=head.logits_dimension,
#     664         feature_columns=feature_columns,
#
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py in _linear_model_fn_builder_v2(units, feature_columns, sparse_combiner, features)
#     597       sparse_combiner=sparse_combiner,
#     598       name='linear/linear_model')
# --> 599   logits = linear_model(features)
#     600   bias = linear_model.bias
#     601
#
# D:\ProgramData\Anaconda3\lib\site-packages\keras\engine\base_layer_v1.py in __call__(self, *args, **kwargs)
#     763               with autocast_variable.enable_auto_cast_variables(
#     764                   self._compute_dtype_object):
# --> 765                 outputs = call_fn(cast_inputs, *args, **kwargs)
#     766
#     767             except tf.errors.OperatorNotAllowedInGraphError as e:
#
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     697       except Exception as e:  # pylint:disable=broad-except
#     698         if hasattr(e, 'ag_error_metadata'):
# --> 699           raise e.ag_error_metadata.to_exception(e)
#     700         else:
#     701           raise
#
# ValueError: in user code:
#
#     File "D:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py", line 1668, in call  *
#         return self.layer(features)
#     File "D:\ProgramData\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py", line 1496, in call  *
#         weighted_sum = fc_v2._create_weighted_sum(  # pylint: disable=protected-access
#
#     ValueError: Feature fare is not in features dictionary.
